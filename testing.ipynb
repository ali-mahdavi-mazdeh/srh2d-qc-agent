# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "src")))

# %%
from pathlib import Path
from src.srh2d_qc.qc_engine.runner import run_all_qc
from src.srh2d_qc.qc_engine.report import generate_markdown_report

# %%
model = load_model(Path(r"C:\my_tools\srh2d-qc-agent\tests\model_1"))
model

# %%
results = run_all_qc(r"C:\my_tools\srh2d-qc-agent\tests\model_2")
print(generate_markdown_report(results))
# Out:
# # SRH‑2D QC Report
#
# ## Mesh Quality
#
# **Elements:** 1
#
# - Min angle range: 45.00° – 45.00°
# - Max angle range: 90.00° – 90.00°
# - Aspect ratio range: 1.41 – 1.41
# - Skewness range: 30.00° – 30.00°
# - Area range: 50.0000 – 50.0000
#
# ## Boundary Condition Consistency
#
#
# ### Inflow1
# _No issues detected_
#
#
#
# ## Material Coverage
#
# - Missing material IDs: _None_
# - Unused material IDs: _None_
#
# ### Element counts per material
# - Material 1: 1 elements
#
#
# ## Timestep Stability
#
# - Model DT: 1.0000 s
# - Minimum geometric DT: 3.1928 s
# - Median geometric DT: 3.1928 s
# - Violating elements: 0
